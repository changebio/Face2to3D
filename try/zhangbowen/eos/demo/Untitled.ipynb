# %%
import eos
import numpy as np
help(eos)
# Out:
# Help on module eos:
#
# NAME
#     eos - Python bindings for the eos 3D Morphable Face Model fitting library.
#
# DESCRIPTION
#     For an overview of the functionality, see the documentation of the submodules. For the full documentation, see the C++ doxygen documentation.
#
# SUBMODULES
#     core
#     fitting
#     morphablemodel
#     pca
#     render
#
# FILE
#     d:\anaconda\envs\tf2alpha\lib\site-packages\eos.cp36-win_amd64.pyd

# %%
help(eos.core)
# Out:
# Help on module eos.core in eos:
#
# NAME
#     eos.core - Essential functions and classes to work with 3D face models and landmarks.
#
# CLASSES
#     pybind11_builtins.pybind11_object(builtins.object)
#         Landmark
#         LandmarkMapper
#         Mesh
#         Rect
#
#     class Landmark(pybind11_builtins.pybind11_object)
#      |  Representation of a landmark, consisting of a landmark name and coordinates of the given type. Usually, the type would be Eigen::Vector2f.
#      |
#      |  Method resolution order:
#      |      Landmark
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: eos.core.Landmark, name: str, coordinates: numpy.ndarray[float32[2, 1]]) -> None
#      |
#      |      Construct a Landmark with the given name (identifier) and point coordinates.
#      |
#      |  __repr__(...)
# ...
